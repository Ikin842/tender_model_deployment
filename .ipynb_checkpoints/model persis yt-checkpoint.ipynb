# %%
import pandas as pd

# %%
df = pd.read_csv('data/data_tender_cirebon.csv')
df
# Out:
#      status_spse sumber_dana                               k_l_pd  \
# 0       spse 4.5        APBD  Pemerintah Daerah Kabupaten Cirebon
# 1       spse 4.5        APBD  Pemerintah Daerah Kabupaten Cirebon
# 2       spse 4.5        APBD  Pemerintah Daerah Kabupaten Cirebon
# 3       spse 4.5        APBD  Pemerintah Daerah Kabupaten Cirebon
# 4       spse 4.5        APBD  Pemerintah Daerah Kabupaten Cirebon
# ...          ...         ...                                  ...
# 2657      spse 3        APBD  Pemerintah Daerah Kabupaten Cirebon
# 2658      spse 3        APBD  Pemerintah Daerah Kabupaten Cirebon
# 2659      spse 3        APBD  Pemerintah Daerah Kabupaten Cirebon
# 2660      spse 3        APBD  Pemerintah Daerah Kabupaten Cirebon
# 2661      spse 3        APBD  Pemerintah Daerah Kabupaten Cirebon
#
#               jenis_tender            metode_pengadaan  metode_pemilihan  \
# 0     Pekerjaan Konstruksi  Pascakualifikasi Satu File            Tender
# 1             Jasa Lainnya  Pascakualifikasi Satu File            Tender
# 2         Pengadaan Barang  Pascakualifikasi Satu File            Tender
# 3     Pekerjaan Konstruksi  Pascakualifikasi Satu File            Tender
# 4     Pekerjaan Konstruksi  Pascakualifikasi Satu File            Tender
# ...                    ...                         ...               ...
# 2657      Pengadaan Barang  Pascakualifikasi Satu File  Lelang Sederhana
# 2658      Pengadaan Barang  Pascakualifikasi Satu File  Lelang Sederhana
# 2659      Pengadaan Barang  Pascakualifikasi Satu File  Lelang Sederhana
# 2660      Pengadaan Barang  Pascakualifikasi Satu File  Lelang Sederhana
# 2661          Jasa Lainnya  Pascakualifikasi Satu File  Lelang Sederhana
#
#                   metode_evaluasi  tahun_anggaran    nilai_pagu    nilai_hps  \
# 0     Harga Terendah Sistem Gugur            2022  4.803358e+08  480335000.0
# 1     Harga Terendah Sistem Gugur            2022  8.166060e+08  774089025.0
# 2     Harga Terendah Sistem Gugur            2022  7.358680e+08  611331803.0
# 3     Harga Terendah Sistem Gugur            2022  8.370000e+08  836075000.0
# 4     Harga Terendah Sistem Gugur            2022  6.000000e+08  600000000.0
# ...                           ...             ...           ...          ...
# 2657  Harga Terendah Sistem Gugur            2015  1.049188e+09  872898000.0
# 2658  Harga Terendah Sistem Gugur            2015  4.207460e+08  349866000.0
# 2659  Harga Terendah Sistem Gugur            2015  1.012122e+09  842859000.0
# 2660  Harga Terendah Sistem Gugur            2015  3.826880e+08  318060000.0
# 2661  Harga Terendah Sistem Gugur            2015  3.600000e+08  360000000.0
#
#                             cara_bayar kualifikasi  jumlah_peserta
# 0     Gabungan Lumsum dan Harga Satuan       Kecil              26
# 1                               Lumsum   Non Kecil              18
# 2                         Harga Satuan       Kecil              23
# 3     Gabungan Lumsum dan Harga Satuan       Kecil              25
# 4     Gabungan Lumsum dan Harga Satuan       Kecil              26
# ...                                ...         ...             ...
# 2657                      Harga Satuan       Kecil               3
# 2658                      Harga Satuan       Kecil               3
# 2659                      Harga Satuan       Kecil               2
# 2660                      Harga Satuan       Kecil               2
# 2661                      Harga Satuan       Kecil              15
#
# [2662 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_spse       2662 non-null   object
#  1   sumber_dana       2662 non-null   object
#  2   k_l_pd            2655 non-null   object
#  3   jenis_tender      2662 non-null   object
#  4   metode_pengadaan  2662 non-null   object
#  5   metode_pemilihan  2662 non-null   object
#  6   metode_evaluasi   2662 non-null   object
#  7   tahun_anggaran    2662 non-null   int64
#  8   nilai_pagu        2662 non-null   float64
#  9   nilai_hps         2662 non-null   float64
#  10  cara_bayar        2662 non-null   object
#  11  kualifikasi       2377 non-null   object
#  12  jumlah_peserta    2662 non-null   int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 270.5+ KB

# %%
df.status_spse.value_counts()
# Out:
# spse 3      1390
# spse 4.3     765
# spse 4       280
# spse 4.5     222
# spse 4.4       5
# Name: status_spse, dtype: int64

# %%
df.kualifikasi.value_counts()
# Out:
# Kecil                   2213
# Non Kecil                122
# Kecil atau Non Kecil      41
# Menengah                   1
# Name: kualifikasi, dtype: int64

# %%
df.replace({
            'status_spse':{'spse 3':0, 'spse 4':1, 'spse 4.3':2, 'spse 4.4':3, 'spse 4.5':4},
            'sumber_dana':{'APBD':0, 'APBDP':1, 'APBN':2, 'Gabungan':3, 'APBNP':4},
            'k_l_pd': {'Pemerintah Daerah Kabupaten Cirebon':0, 'Pemerintah Daerah Provinsi Jawa Barat':1, 'Kementerian Agama':2},
            'jenis_tender': {'Pekerjaan Konstruksi':0, 'Jasa Konsultansi Badan Usaha':1, 'Pengadaan Barang':2, 'Jasa Konsultansi Badan Usaha Non Konstruksi':3, 'Jasa Konsultansi Badan Usaha Konstruksi':4, 'Jasa Lainnya':5},
            'metode_pengadaan': {'Pascakualifikasi Satu File':0, 'Prakualifikasi Dua File':1, 'Prakualifikasi Satu File':2},
            'metode_pemilihan': {'Lelang Pemilihan Langsung':0, 'Tender':1, 'Lelang Sederhana':2, 'Seleksi Sederhana': 3, 'Seleksi':4, 'Seleksi Umum':5, 'Tender Cepat':6, 'Lelang Umum':7, 'Pengadaan Langsung':8},
            'metode_evaluasi': {'Harga Terendah Sistem Gugur':0, 'Kualitas dan Biaya':1, 'Pagu Anggaran':2, 'Biaya Terendah':3},
            'cara_bayar': {'Gabungan Lumsum dan Harga Satuan':0, 'Lumsum':1, 'Harga Satuan':2, 'Persentase':3},
            'kualifikasi': {'Kecil':0, 'Non Kecil':1, 'Kecil atau Non Kecil': 2, 'Menengah':3}
           }, inplace=True)

# %%
df
# Out:
#       status_spse  sumber_dana  k_l_pd  jenis_tender  metode_pengadaan  \
# 0               4            0     0.0             0                 0
# 1               4            0     0.0             5                 0
# 2               4            0     0.0             2                 0
# 3               4            0     0.0             0                 0
# 4               4            0     0.0             0                 0
# ...           ...          ...     ...           ...               ...
# 2657            0            0     0.0             2                 0
# 2658            0            0     0.0             2                 0
# 2659            0            0     0.0             2                 0
# 2660            0            0     0.0             2                 0
# 2661            0            0     0.0             5                 0
#
#       metode_pemilihan  metode_evaluasi  tahun_anggaran    nilai_pagu  \
# 0                    1                0            2022  4.803358e+08
# 1                    1                0            2022  8.166060e+08
# 2                    1                0            2022  7.358680e+08
# 3                    1                0            2022  8.370000e+08
# 4                    1                0            2022  6.000000e+08
# ...                ...              ...             ...           ...
# 2657                 2                0            2015  1.049188e+09
# 2658                 2                0            2015  4.207460e+08
# 2659                 2                0            2015  1.012122e+09
# 2660                 2                0            2015  3.826880e+08
# 2661                 2                0            2015  3.600000e+08
#
#         nilai_hps  cara_bayar  kualifikasi  jumlah_peserta
# 0     480335000.0           0          0.0              26
# 1     774089025.0           1          1.0              18
# 2     611331803.0           2          0.0              23
# 3     836075000.0           0          0.0              25
# 4     600000000.0           0          0.0              26
# ...           ...         ...          ...             ...
# 2657  872898000.0           2          0.0               3
# 2658  349866000.0           2          0.0               3
# 2659  842859000.0           2          0.0               2
# 2660  318060000.0           2          0.0               2
# 2661  360000000.0           2          0.0              15
#
# [2662 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_spse       2662 non-null   int64
#  1   sumber_dana       2662 non-null   int64
#  2   k_l_pd            2655 non-null   float64
#  3   jenis_tender      2662 non-null   int64
#  4   metode_pengadaan  2662 non-null   int64
#  5   metode_pemilihan  2662 non-null   int64
#  6   metode_evaluasi   2662 non-null   int64
#  7   tahun_anggaran    2662 non-null   int64
#  8   nilai_pagu        2662 non-null   float64
#  9   nilai_hps         2662 non-null   float64
#  10  cara_bayar        2662 non-null   int64
#  11  kualifikasi       2377 non-null   float64
#  12  jumlah_peserta    2662 non-null   int64
# dtypes: float64(4), int64(9)
# memory usage: 270.5 KB
